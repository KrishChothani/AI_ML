# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishChothani/AI_ML/blob/main/ML_Pract_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import pytesseract as py

image=Image.open("test.jpg")
text=py.image_to_string(image)
print(text)
# Out:
# ee ee ee ert ROM 1d
#
# € RB
#
# aCoM alae a
# Poy eee Oy 1:
#
# ai Fol @)
#
#
#
# Pay again
#
# © Completed
#
# 25 Jul 2025, 5:49 pm
#
# (Gi) State Bank of India 5225 v
#
# UPI transaction ID
# 557294201873
#
# To: Mr HARSH KIRANKUMAR SURTI
# Google Pay « surtiharsh2@okaxis
#
# From: CHOTHANI KRISH RAMESHBHAI
# (State Bank of India)
#
# Google Pay « krishchothani259@okicici
#
#
#
# @® Having Retceeal < Share |
#
#
#
# 2. Split w

# %%
from pdf2image import convert_from_path
import pytesseract as py

pages=convert_from_path("Miheer H.pdf")

for page in pages:
    text=py.image_to_string(page)
    print(f"\n Page  --> \n\n {text}")
# Out:
#  Page  -->
#
#  A manupatra®
#
# M jheerH .M afatlalVs.M afatlalIndustries Ltd*: A Case Study
# - ChhaviAgam al*
#
# The Court sanctioned a Scheme of Amalgam ation of two Publc Lm ited com pangs,
# nam el Mafathl Industres Lin ited (MIL') beng the transferee-com pany with whih
# MafatalFinne Spinning and Manufacturng Com pany Lim ited (MFL' for short) beng the
# transferor-com pany was to be am alam ated. In order to appreciate the grevance of the
#
# appelant it w illbe necessary to glance through a few rekvant background facts.
# PART I: FACTS OF THE SITUATION :
#
# The respondent-com pany MIL was wncorporated n 1913 under the name ‘The New
# Shorrock Spnning & Manufacturng Co. Lim ited'and its nam e was subsequenty changed
# to Mafatll Industries Lin ited'as per the fresh Certificate of Incorporation n Jan’74 as
# sanctioned by the Registrar of Com pan#s. The objects of the transferee-com pany MIL as
#
# ...

# %%
# !pip install pytesseract

# %%
# !pip install pillow pdf2image

# %%
# !apt-get update
# !apt-get install poppler-utils
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,898 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,773 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...
